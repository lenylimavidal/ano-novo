# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from IPython.display import display, HTML
from collections import Counter
import seaborn as sns

# %%
# Crear un DataFrame con mensajes de Año Nuevo en portugués
data = {
    "Mensagem": [
        "Feliz Ano Novo",
        "Saúde",
        "Sucesso",
        "Prosperidade",
        "Amor",
        "Alegria",
        "Esperança",
        "Paz",
        "Felicidade",
        "Harmonia",
        "Bênçãos",
        "Riquezas",
        "União",
        "Gratidão",
        "Sabedoria",
        "Fortaleza",
        "Renovação",
    ]
}

# %%
df = pd.DataFrame(data)

# %%
# Función para aplicar estilos al DataFrame
def style_dataframe(df):
    return df.style.set_properties(
        **{
            "color": "white",
            "background-color": "#007bff",
            "font-weight": "bold",
            "font-size": "18px",
            "border": "2px solid #000",
            "text-align": "center",
        }
    )

# %%
# Mostrar el DataFrame estilizado
styled_df = style_dataframe(df)
display(HTML("<h3 style='color: #2d572c;'>Desejos de Ano Novo: Um ano abençoado e próspero!</h3>"))
display(styled_df)
# Out:
# <h3 style='color: #2d572c;'>Desejos de Ano Novo: Um ano abençoado e próspero!</h3>
# <style type="text/css">
# #T_74ffe_row0_col0, #T_74ffe_row1_col0, #T_74ffe_row2_col0, #T_74ffe_row3_col0, #T_74ffe_row4_col0, #T_74ffe_row5_col0, #T_74ffe_row6_col0, #T_74ffe_row7_col0, #T_74ffe_row8_col0, #T_74ffe_row9_col0, #T_74ffe_row10_col0, #T_74ffe_row11_col0, #T_74ffe_row12_col0, #T_74ffe_row13_col0, #T_74ffe_row14_col0, #T_74ffe_row15_col0, #T_74ffe_row16_col0 {
#   color: white;
#   background-color: #007bff;
#   font-weight: bold;
#   font-size: 18px;
#   border: 2px solid #000;
#   text-align: center;
# }
# </style>
# <table id="T_74ffe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74ffe_level0_col0" class="col_heading level0 col0" >Mensagem</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74ffe_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
# Generar texto para la nube de palabras
text = " ".join(df["Mensagem"])

# %%
# Crear una nube de palabras
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color="white",
    colormap="viridis",
    max_font_size=100
).generate(text)

# %%
# Mostrar la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Feliz Ano Novo 2025", fontsize=16)
plt.show()

# %% [markdown]
# ### Gráfico de barras sin frecuencias, solo ensayo

# %%
# Contar la frecuencia de palabras
from collections import Counter
word_counts = Counter(" ".join(df["Mensagem"]).split())

# %%
# Crear un DataFrame con las frecuencias
freq_df = pd.DataFrame(word_counts.items(), columns=["Palavra", "Frequência"]).sort_values(by="Frequência", ascending=False)

# %%
# Visualizar con un gráfico de barras
plt.figure(figsize=(10, 6))
sns.barplot(data=freq_df, x="Frequência", y="Palavra", palette="viridis")
plt.title("Frequência das Palavras nos Desejos de Ano Novo", fontsize=16)
plt.xlabel("Frequência", fontsize=12)
plt.ylabel("Palavra", fontsize=12)
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19532\3758591353.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=freq_df, x="Frequência", y="Palavra", palette="viridis")

# %%
# Datos de palabras con emociones asociadas
data_emociones = {
    "Palavra": [
        "Felicidade", "Alegria", "Esperança", "Amor", "Paz", 
        "Sabedoria", "Força", "Renovação", "Unidade", 
        "Gratidão", "Ansiedade", "Medo", "Incerteza", "Harmonia", "Sucesso"
    ],
    "Emoção": [
        "Alegria", "Alegria", "Esperança", "Amor", "Esperança", 
        "Esperança", "Esperança", "Esperança", "Amor", 
        "Amor", "Ansiedade", "Medo", "Medo", "Esperança", "Alegria"
    ]
}

# %%
df_emociones = pd.DataFrame(data_emociones)

# %%
# Calcular frecuencias ajustadas manualmente para balancearlas
data_ajustada = {
    "Emoção": ["Alegria", "Esperança", "Medo", "Amor", "Ansiedade", "Felicidade", "Sucesso"],
    "Frecuencia": [6, 6, 5, 5, 4, 4, 4]  # Distribución más equilibrada
}

# %%
df_ajustada = pd.DataFrame(data_ajustada)

# %%
# Calcular frecuencias ajustadas manualmente para balancearlas
data_ajustada = {
    "Emoção": ["Alegria", "Esperança", "Medo", "Amor", "Ansiedade", "Felicidade", "Sucesso"],
    "Frecuencia": [6, 6, 5, 5, 4, 4, 4]  # Distribución más equilibrada
}

# %%
df_ajustada = pd.DataFrame(data_ajustada)

# %%
# Calcular probabilidades ajustadas para 2024
total_palabras_2024 = df_ajustada["Frecuencia"].sum()
df_ajustada["Probabilidade_2024"] = df_ajustada["Frecuencia"] / total_palabras_2024

# %%
# Predicción para 2025 con un incremento del 5%
total_palabras_2025 = total_palabras_2024 * 1.05
df_ajustada["Predição_2025"] = df_ajustada["Probabilidade_2024"] * total_palabras_2025

# %%
# Mostrar el DataFrame ajustado
print("Predicción simbólica de emociones para 2025:")
print(df_ajustada)
# Out:
# Predicción simbólica de emociones para 2025:
#        Emoção  Frecuencia  Probabilidade_2024  Predição_2025
# 0     Alegria           6            0.176471           6.30
# 1   Esperança           6            0.176471           6.30
# 2        Medo           5            0.147059           5.25
# 3        Amor           5            0.147059           5.25
# 4   Ansiedade           4            0.117647           4.20
# 5  Felicidade           4            0.117647           4.20
# 6     Sucesso           4            0.117647           4.20

# %%
# Crear gráfico de barras para la predicción de emociones en 2025
plt.figure(figsize=(10, 6))
colores = {
    "Alegria": "gold",
    "Esperança": "green",
    "Medo": "red",
    "Amor": "purple",
    "Ansiedade": "blue",
    "Felicidade": "pink",
    "Sucesso": "orange"
}
plt.bar(
    df_ajustada['Emoção'], 
    df_ajustada['Predição_2025'], 
    color=[colores[emo] for emo in df_ajustada['Emoção']]
)

# Agregar etiquetas y título con ajustes
plt.xlabel('Categorias de Emoções')  
plt.ylabel('Frequência em 2024') 
plt.title('Predicción de Frecuencia de Emociones en 2025')

# Mostrar valores encima de las barras
for i, v in enumerate(df_ajustada['Predição_2025']):
    plt.text(i, v + 0.1, f'{v:.2f}', ha='center', va='bottom', fontsize=10)

# Mostrar el gráfico
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
